# %%
import pandas as pd

dataFrame = pd.read_csv("https://raw.githubusercontent.com/zief0002/epsy-5261/main/data/countries.csv")

# %%
dataFrame.columns
# Out:
# Index(['country', 'region', 'population', 'area', 'gdp', 'life_expect',
#        'birth_rate', 'fertility_rate', 'death_rate', 'infant_mortality'],
#       dtype='str')

# %%
dataFrame[["country", "population"]]
dataFrame.iloc[10]["country"]
# Out:
# 'Azerbaijan'

# %%
dataFrame.head()
dataFrame[dataFrame["area"] > 300000]
# Out:
#            country                      region  population       area  \
# 0      Afghanistan                  South Asia  38041754.0   652860.0
# 2          Algeria  Middle East & North Africa  43053054.0  2381741.0
# 3           Angola          Sub-Saharan Africa  31825295.0  1246700.0
# 5        Argentina   Latin America & Caribbean  44938712.0  2780400.0
# 8        Australia         East Asia & Pacific  25365745.0  7741220.0
# ..             ...                         ...         ...        ...
# 189  Venezuela, RB   Latin America & Caribbean  28515829.0   912050.0
# 190        Vietnam         East Asia & Pacific  96462106.0   331230.0
# 193    Yemen, Rep.  Middle East & North Africa  29161922.0   527970.0
# 194         Zambia          Sub-Saharan Africa  17861030.0   752610.0
# 195       Zimbabwe          Sub-Saharan Africa  14645468.0   390760.0
#
#               gdp  life_expect  birth_rate  fertility_rate  death_rate  \
# ...

# %%
dataFrame[dataFrame["country"] == "Poland"]
dataFrame[dataFrame["country"].str.startswith("P")]
dataFrame[~dataFrame["country"].str.startswith("P")] #~reverse operation
# Out:
#                    country                      region  population       area  \
# 0              Afghanistan                  South Asia  38041754.0   652860.0
# 1                  Albania       Europe & Central Asia   2854191.0    28750.0
# 2                  Algeria  Middle East & North Africa  43053054.0  2381741.0
# 3                   Angola          Sub-Saharan Africa  31825295.0  1246700.0
# 4      Antigua and Barbuda   Latin America & Caribbean     97118.0      440.0
# ..                     ...                         ...         ...        ...
# 191  Virgin Islands (U.S.)   Latin America & Caribbean    106669.0      350.0
# 192     West Bank and Gaza  Middle East & North Africa   4685306.0     6020.0
# 193            Yemen, Rep.  Middle East & North Africa  29161922.0   527970.0
# 194                 Zambia          Sub-Saharan Africa  17861030.0   752610.0
# 195               Zimbabwe          Sub-Saharan Africa  14645468.0   390760.0
#
# ...

# %%
dataFrame.loc[dataFrame["country"] == "Poland"]
dataFrame["country"] = dataFrame["country"].str.upper()

# %%
dataFrame["country"]
# Out:
# 0                AFGHANISTAN
# 1                    ALBANIA
# 2                    ALGERIA
# 3                     ANGOLA
# 4        ANTIGUA AND BARBUDA
#                ...
# 191    VIRGIN ISLANDS (U.S.)
# 192       WEST BANK AND GAZA
# 193              YEMEN, REP.
# 194                   ZAMBIA
# 195                 ZIMBABWE
# Name: country, Length: 196, dtype: str

# %%
dataFrame.dropna()
dataFrame.fillna({"population": 0}, inplace = True)
# Out:
#                    country                      region  population       area  \
# 0              AFGHANISTAN                  South Asia  38041754.0   652860.0
# 1                  ALBANIA       Europe & Central Asia   2854191.0    28750.0
# 2                  ALGERIA  Middle East & North Africa  43053054.0  2381741.0
# 3                   ANGOLA          Sub-Saharan Africa  31825295.0  1246700.0
# 4      ANTIGUA AND BARBUDA   Latin America & Caribbean     97118.0      440.0
# ..                     ...                         ...         ...        ...
# 191  VIRGIN ISLANDS (U.S.)   Latin America & Caribbean    106669.0      350.0
# 192     WEST BANK AND GAZA  Middle East & North Africa   4685306.0     6020.0
# 193            YEMEN, REP.  Middle East & North Africa  29161922.0   527970.0
# 194                 ZAMBIA          Sub-Saharan Africa  17861030.0   752610.0
# 195               ZIMBABWE          Sub-Saharan Africa  14645468.0   390760.0
#
# ...
